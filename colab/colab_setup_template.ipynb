# %% [markdown]
# # Colab Setup Template

# %%
from google.colab import drive

drive.mount('/content/drive')

# %%
# !git clone <YOUR_GITHUB_REPO_URL>
# %cd pr-risk-active-learning

# %%
# %pip install -r requirements-colab.txt

# %%
# !nvidia-smi

# %%
import sys

sys.path.append('/content/pr-risk-active-learning/src')
from pr_risk.data.load_data import load_csv

print("pr_risk imported successfully:", load_csv.__name__)
